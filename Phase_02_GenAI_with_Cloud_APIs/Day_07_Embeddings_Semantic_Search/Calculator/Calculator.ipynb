# %%
# !pip install llama-index llama-index-llms-groq sentence-transformers --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.9/588.9 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 67.9 MB/s eta 0:00:00

# %%
# !pip install llama-index-embeddings-huggingface --q

# %%
import os
from textwrap import dedent   #if we write python file it downaod .txt file

os.makedirs("data",exist_ok=True)

file_path="data/Data.txt"

content=dedent("""
Name of the Event	Resource Person
Date
1	Mastering in MLO ps	Mr. C.B. Veerakumar, Associate Engineering Analyst, Wipro Technologies	02.07.25–18.07.25
2	Introduction to Data Bricks	Ms. K. Parvathy, AP/AI&DS	03.05.25
3	Fundamentals of Generative AI	Ms. K. Parvathy, AP/AI&DS	29.04.25
4	Hand-on Session on Exploratory Data Analysis	Ms. K. Parvathy, AP/AI&DS	05.04.25
5	Basics of Business Intelligence	Ms. K. Parvathy, AP/AI&DS	05.04.25
6	Data Visualization Tools and Techniques	Ms. K. Parvathy, AP/AI&DS	15.03.25
7	Hands-on Session on Power BI	Ms. K. Parvathy, AP/AI&DS	15.02.25
8	Introduction to Data Visualization	Ms.K.Parvathy, AP/AI&DS	28.12.2024
9	Data Visualization using Power BI	Ms. Ramalakshmi, IV AIDS	30.11.2024
10	(FN) Hand on Data Analytics using Excel Worksheets	Mr. M. Sangarapandian & Mr. N. Sri Harikrishna, III AIDS B	23.11.2024
11	(AN) Hands on Data Analytics and Visualization using Orange	Mr. M. Sangarapandian & Mr. N. Sri Harikrishna, III AIDS B	23.11.2024
12	Innovative Roadmap of Data Science	Gokul C, Likith Kumar, IV AI&DS	09.11.2024
13	Open for Innovation KNIME - Overview of KNIME Software	Mr.Sangarapandian and Mr.Yaswanth Saran Sundar, III AI&DS	26.10.2024
14	Data Science in Action: Mastering Innovation Through Hands-On Learning	Mr Shreenivasan S N, Data Analyst, LatentView Analytics	19.10.2024
15	(FN) Innovating with Data Science Foundations	Mr.Sangarapandian and Mr.Yaswanth Saran Sundar, SECE	05.10.2024
16	(AN) Evolution of GenAI on Cloud Platform	Mr.Aashu Dev, AWS Certified Trainer, AWS Academy	05.10.2024
17	Innovative Feature Engineering Demystified: Transforming Data with Python for Cutting-Edge Solutions	Ms. Bhuvaneswari, Corporate Trainer and Mentor, Imarticus Learning	14.09.2024
18	Mastering Data Science Basics: A Practical Approach to Data Loading, Cleaning, and Visualization	Mr.C.B.Veerakumar, Associate Engineering Analyst, Wipro Technologies	31.08.2024
19	Data Science	Mr.G.Rajesh Mani Kumar, Solution Engineer, Proximus, Brussels, Belgium	24.08.2024
20	Data Science Bootcamp: Mastering Data from Wrangling to Visualization	Mr.S.Manikandan, Director, Geons Logix Pvt Ltd	29.07.2024 to 14.08.2024
21	Data Science in Practice: Real-world Applications and Case Studies	Mr.Ramkumar I, Project Manager, Cognizant Technologies	25.05.2024
22	Data Visualization Using Power BI	Dr. M. Nivaashini	11.05.2024
23	Mastering Data Science: Techniques for Analysis and Interpretation	Mr. Gokulakrishnan M, Project Associate, IIT Madras	27.04.2024
24	The Power of Data: Empowering Decision Making with Data Science	Dr.M.Lakshmi, AP/AIDS	19.04.2024
25	Data-driven Discovery using Tableau	Dr.M.Lakshmi, AP/AIDS	09.03.2024
26	Cracking the Data Code: Essential Principles of Data Science	Dr.M.Lakshmi, AP/AIDS	24.02.2024
""").strip()

with open(file_path,"w",encoding="utf-8") as f:
  f.write(content)
print("Created file")
# Out:
# Created file

# %%
import os
from llama_index.llms.groq import Groq
from llama_index.core import SimpleDirectoryReader,VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

os.environ["GROQ_API_KEY"]="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"

llm=Groq(model="llama-3.1-8b-instant")

embed_model=HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")

documents=SimpleDirectoryReader(input_files=[file_path]).load_data()

#create index(with custom embed model)
index=VectorStoreIndex.from_documents(documents,embed_model=embed_model)

#create query engine
query_engine=index.as_query_engine(llm=llm)

#Ask question
response=query_engine.query("Summarize the context of this document in 3 bullet points")
print(response)
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %%
file_path2="data/Resume.txt"

content=dedent("""
CODING PROFILES
EDUCATION
B.Tech - AI & DS Sri Eshwar College of Engineering CGPA : 8.07 (upto 3rd semester) 2024-2028
HSC Best Matric Higher Secondary School 92.67 % 2023-2024
SSLC Lions Club Matriculation School 86.6 % 2021-2022
PROGRAMMING LANGUAGE : C | C++ Basics | Java | Python
WEB TECHNOLOGIES : HTML | CSS | JavaScript | React | Express JS | Node JS | JavaFX
SKILLS : DSA | DBMS | Full-Stack dev(MERN) | UI design | Spring-boot | OOPS
TOOLS : VS code | Collab | Excel | MySQL Workbench | CodeBlocks | PowerBI | Canva |
DATABASE : MongoDB | MySQL
VERSION CONTROL : Git and Github
:
CERTIFICATIONS
LeetCode : Ashwin_2008
Basics in HTML, CSS & JavaScript (Udemy) — 2023|
Mastering Data Structures & Algorithms using C & C++ (Udemy) — 2022|
Python Certification (HackerRank)|C++ Certification (GeeksforGeeks)
Java Programming-Oracle
|Max Rating: 1474 | 450+ PROBLEMS SOLVED
HackerRank : ashwin_s2024aids
|Earned 2 Bronze badges and 1 Silver badge in Python challenges
ASHWIN S
ashwin.s2024aids@sece.ac.in LINKEDIN : Ashwin S P H O N E 8438294452 EMA I L GITHUB Ashwin-2008
Projects
Voice-controlled application launcher that allows users to open apps hands-free, improving
accessibility and ease of use.
Fake News Detection
My data science project focuses on detecting fake news using machine learning techniques. It
analyzes text patterns and linguistic features to classify news articles as real or fake with high
accuracy.
Voice App Launcher
EduMentor
EduMentor is a web-based platform that connects students with mentors for personalized academic
guidance and support.Enables users to book mentoring sessions, track progress, and communicate
seamlessly through an integrated dashboard.
Code Chef : 300+ Problems Solved |Bronze Badge
SKILL RACK : 1400+ Problems Solved|Multiple Certificates Earned
AtCoder : Solved 45+ Problem
SKILLS
Tech Stack-Python
Tech Stack-Python
Tech Stack-MERN
""").strip()

with open(file_path,"w",encoding="utf-8") as f:
  f.write(content)
print("Created file")
# Out:
# Created file

# %%
documents=SimpleDirectoryReader(input_files=[file_path2]).load_data()

#create index(with custom embed model)
index=VectorStoreIndex.from_documents(documents,embed_model=embed_model)

#create query engine
query_engine=index.as_query_engine(llm=llm)

#Ask question
response=query_engine.query("Can I hire him?")
print(response)
# Out:
# It's difficult to make a hiring decision based solely on a resume. However, it's clear that this individual has a strong educational background, with a high CGPA in their B.Tech program. They also have a good track record of solving problems on various coding platforms, including LeetCode, HackerRank, and AtCoder. Additionally, they have experience with a range of technologies, including Python, MERN, and MongoDB.
#
# Their project experience, particularly with the Voice-controlled application launcher and the EduMentor platform, suggests that they have a good understanding of software development principles and can apply them to real-world problems. They also have experience with machine learning techniques, which is a valuable skill in today's tech industry.
#
# Overall, this individual appears to have a solid foundation in computer science and software development, and their skills and experience make them a strong candidate for a technical role.

# %%
# !pip install langchain langchain-community langchain-groq faiss-cpu sentence-transformers PyPDF2 pypdf --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 59.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 72.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.9/343.9 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
